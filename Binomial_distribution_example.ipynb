# %% [markdown]
# ##Problem Statement
#
# A bank issues credit cards to customers under the scheme of Master
# Card. Based on the past data, the bank has found out that 60% of all
# accounts pay on time following the bill. If a sample of 7 accounts is
# selected at random from the current database, construct the Binomial
# Probability Distribution of accounts paying on time.

# %%
#importing libraries 

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
#Probability of people paying the amount on time 
p=0.6

# %%
n=7

# %%
k=np.arange(0,8)

# %%
binomial= stats.binom.pmf(k,n,p)

# %%
binomial
# Out:
# array([0.0016384, 0.0172032, 0.0774144, 0.193536 , 0.290304 , 0.2612736,
#        0.1306368, 0.0279936])

# %%
plt.plot(k,binomial, 'o-')
plt.title("Binomial")
plt.xlabel("No of account paying on time")
plt.ylabel("Probabilty of accounts paying on time")
# Out:
# Text(0, 0.5, 'Probabilty of accounts paying on time')
